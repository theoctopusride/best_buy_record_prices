# %%
from bs4 import BeautifulSoup

# %%
bb1 = "https://www.bestbuy.com/site/music/vinyl-records/pcmcat197800050048.c?cp="
count = 1
bb2 = "&id=pcmcat197800050048"

# %%
import requests

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:68.0)'}
page = requests.get(bb1 + str(count) + bb2, headers=headers)

# %%
soup = BeautifulSoup(page.text, 'html.parser')
artist_sku_release_date = soup.find_all('div', class_="sku-model")
title = soup.find_all('div', class_="sku-title")
price = soup.find_all('div', class_="priceView-hero-price priceView-customer-price")
in_stock = soup.find_all('div', class_="fulfillment-add-to-cart-button")
# Out:
# <!DOCTYPE HTML>
# <html lang="en">
#  <head>
#   <!-- platview-njs: version=19.31.3 | blueprint: id=plp-holiday-browse-l -->
#   <!-- start simple component shop-plp-seo-metadata-929240e1-aa0e-48ef-88d3-9ef59b49a243 - shop-plp-seo-metadata v1 -->
#   <title>
#    Vinyl Records &amp; LPs - Best Buy
#   </title>
#   <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="no-cache" http-equiv="pragma"/>
#   <meta content="no-cache" http-equiv="cache-control"/>
#   <meta content="-1" http-equiv="expires"/>
#   <meta content="width=1024" name="viewport"/>
#   <meta content="Shop vinyl records and LPs at BestBuy.com. Find hundreds of titles from pop and rock musicians, rap artists, reggae bands and more." name="description"/>
#   <meta content="record, music records, records, vinyl records" name="keywords"/>
#   <link href="//www.bestbuy.com/favicon.ico" rel="icon" type="image/x-icon"/>
#   <link href="https://www.bestbuy.com/site/music/vinyl-records/pcmcat197800050048.c?id=pcmcat197800050048" rel="canonical"/>
#   <link href="https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&amp;browsedCategory=pcmcat197800050048&amp;cp=2&amp;id=pcat17071&amp;iht=n&amp;ks=960&amp;list=y&amp;sc=Global&amp;st=pcmcat197800050048_categoryid%24cat02001&amp;type=page&amp;usc=All%20Categories" rel="next"/>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.bestbuy.com/","name":"Best Buy"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.bestbuy.com/site/electronics/movies-music/abcat0600000.c?id=abcat0600000","name":"Movies & Music"}},{"@type":"ListItem","position":3,"item":{"@id":"https://www.bestbuy.com/site/movies-music/music/cat02001.c?id=cat02001","name":"Music"}}]}
#   </script>
#   <!-- end simple component shop-plp-seo-metadata-929240e1-aa0e-48ef-88d3-9ef59b49a243 - shop-plp-seo-metadata v1 -->
#   <!-- start simple component shop-optimizely-c90ef106-9837-47e4-b5d7-a0446157fbb7 - shop-optimizely v1 -->
#   <script src="/~assets/bby/_js/ext/optmzly/8143030612.js">
#   </script>
#   <!-- end simple component shop-optimizely-c90ef106-9837-47e4-b5d7-a0446157fbb7 - shop-optimizely v1 -->
#   <link href="https://assets.bbystatic.com/header-footer/main-l-b1dea9bbdf89e67c1162c4b1dd232585.css" rel="stylesheet" type="text/css"/>
#   <link href="https://assets.bbystatic.com/header-footer/images/favicon-32.png" rel="icon" sizes="32x32"/>
#   <meta content="BestBuy.com" name="application-name"/>
#   <meta content="BestBuy - Let's talk about what's possible." name="msapplication-tooltip"/>
#   <meta content="https://assets.bbystatic.com/header-footer/images/ieconfig.xml" name="msapplication-config"/>
#   <link href="https://assets.bbystatic.com/header-footer/images/favicon-152.png" rel="apple-touch-icon-precomposed"/>
#   <script src="https://assets.bbystatic.com/header-footer/core-js-shim-2.5.6.min.js">
#   </script>
#   <script src="https://assets.bbystatic.com/header-footer/fetch-2.0.4.min.js">
#   </script>
#   <script src="https://assets.bbystatic.com/header-footer/aq-3.0.0.min.js">
#   </script>
#   <script data-perc="0" id="delta-measure" src="https://assets.bbystatic.com/header-footer/delta-44d00a319ee512afc5c3.js">
#   </script>
#   <script src="/~assets/bby/_js/ext/optmzly/8143030612.js">
#   </script>
#   <link href="https://assets.bbystatic.com/suggest/suggest-view-client-l-b4dba0f0823911e9b087f7173125b100.css" media="all" rel="stylesheet" type="text/css"/>
#   <script>
#    "use strict";var config=window.liveConfig||{},probability=config.duxValidate||0;if("function"==typeof jQuery&&probability>0&&probability<=1){var result=Math.random()<probability;(1===probability||result)&&!function(){var i={"name":"suggestViewClientComponent","dependencies":{"css":[{"file":"/suggest/suggest-view-client-l-b4dba0f0823911e9b087f7173125b100.css"}],"js":[]}};if(i.content=window.jQuery("div[data-dux-component="+'suggestViewClientComponent'+"]").html()||"","function"!=typeof window.__duxValidate__){var a=document.createElement("script");a.onload=function(){return window.__duxValidate__(i)},a.src=''+"/lib-dux/dist/validate-"+"a069b97f2596d0f28de17826cac506c6"+".js",document.body.appendChild(a)}else window.__duxValidate__(i)}()}
#   </script>
#   <script>
#    document.domain = 'bestbuy.com';
#
# 			if (typeof window.rdpClass === 'undefined') {
# 				window.rdpClass = {};
# 			}
#
# 			window.rdpClass.deviceClass = 'l';
#
# 			if (typeof window._metaLayer === 'undefined') {
# 				window._metaLayer = {};
# 			}
#
# 			window._metaLayer.device_deviceClass = 'l';
# 			window._metaLayer.user_rzTier = 'None';
# 			window._metaLayer.env_falcor = '/api/tcfb';
# 			window._metaLayer.env_assets = 'https://assets.bbystatic.com';
# 			window._metaLayer.env_piscesUrl = 'https://pisces.bbystatic.com';
# 			window._metaLayer.env_pisces = 'https://pisces.bbystatic.com';
#   </script>
#   <link href="https://assets.bbystatic.com/sc-pattern-library/2.27.1/dist/css/pattern-library.min.css" media="all" rel="stylesheet"/>
#   <script>
#    function _setUpConfigService () {
# 							window.configService = getConfigService({"abt1501evar":"abTest68","priceViewOfferProductPriceGlobal":true,"AutoCompare_enableRecommendations":true,"CompareAddStructureEnabled":true,"HF_enableDynamicStoreLocator":true,"HF_enableNotificationManager":true,"HF_logoImageHash":"968d1f5f01d288d23e3b2c71de31967a","HF_notificationsHideWaitTimeMS":3000,"HF_shoppingHistoryToastEnabled":false,"HF_shoppingHistoryToastVersion":"V1","PLPFacetRedirectDelay":1,"TestLiveConfig":"Works","attachSuggestPageTypes":"browse,pdp","basketAddProbability":1,"beagleApiPath":"/wireless","blueAssistEnabled":true,"bonusContentFlag":true,"clickToCallClientKey":"n9fzQiKTTx7cBIT1FiRj8x0B3lqX/kMFgbwW8uRRuqc=","clickToCallGetEndpoint":"https://bbytagservices.bestbuy.com/Generic/BBYClickToCallServiceREST/api/click2Call","clickToCallPostEndpoint":"https://bbytagservices.bestbuy.com/Generic/BBYClickToCallServiceREST/api/click2Call","compareDisabled":false,"coralAssetId":"522e93e4-a28b-498d-b1cb-8fd0f6d468f7","components":"[shop:[attach-modal:[useAttachSuggest:true], complete-your-purchase:[singleSelectDCS:[[department:4, class:205]]], office-365:[useNew365Render:true], solution-banner:[enableSolutionAssemblerLinks:true], solution-button:[enableSolutionAssemblerLinks:true]]]","custTimeline_accountFingerprint":"0.2.0","custTimeline_compareWhitelist":"[]","custTimeline_enableExperience":"[s, m, l]","custTimeline_enableInGlobalNav":true,"custTimeline_enableListener":true,"custTimeline_experienceFingerprint":"2.0.23","custTimeline_headerExperienceFingerprint":"2.1.11","custTimeline_headerStatusFingerprint":"2.0.17","custTimeline_initialForcedCollapsed":false,"custTimeline_listenerFingerprint":"1.10.9","custTimeline_loaderFingerprint":"1.0.648","custTimeline_shoppingHistoryWhitelist":"[browse,home]","custTimeline_showRecommendationsInShoppingHistory":true,"custTimeline_useIndividualDataTopics":true,"disableAddToCartStips":true,"disableBuyingOptionsStips":true,"disableCmmStips":true,"disableCompareStips":true,"disableConditionalOptionsStips":true,"disableDynamicPricingCalls":true,"disableEnlargeImageStips":true,"disableFridayInStoreOnlyStips":true,"disableHolidayIspuDateStips":true,"disableHolidayLsaStips":true,"disableHolidayVddcStips":true,"disableIspuAvailabilityStips":true,"disablePLPCheckMarkMessagingAndDescription":true,"disablePriceStips":true,"disableRewardsStips":true,"disableSaturdayInStoreOnlyStips":true,"disableShelfRequests":false,"disableShippingPuckStips":true,"disableTextWidgetStips":true,"dynamicPricingProbability":1,"dynamicPricingRender":true,"enableAbCys":false,"enableBrandImage":false,"enableClickToCall":true,"enableCys":true,"enableDynamicGWP":true,"enableEcoRebates":true,"enableEmailSubmissionModal":true,"enableEndOfLifeInventory":true,"enableEnsighten":true,"enableFulfillmentCompare":true,"enableFulfillmentPLP":true,"enableGeoVars":true,"enableGetLocationCache":true,"enableGuidedBuyingPlpIntegration":true,"enableGvpCyp":true,"enableImageFixStips":true,"enableInStoreOnlyButton":false,"enableInkSubscription":true,"enableIspuPLP":true,"enableLegacyAvailability":false,"enableLocationProfileApi":true,"enableLocationProfileApiRead":true,"enableMobileStoreSet":true,"enableMoveAddToCartButton":true,"enableNewAddToCartButtonPDP":true,"enableNewAddToCartButtonPLP":true,"enableNewButtonStateForHydrateSku":true,"enableNotifyInStockV2":true,"enableNotifyMe":true,"enablePDPCompareTray":true,"enablePhoenixInTheCloudPLP":true,"enablePhoenixPDP":true,"enablePmgStips":false,"enableSaveForLater":true,"enableSearchSurveyPLP":true,"enableShelfDisplayV2":true,"enableShoppingAssistant":true,"enableSmallViewChat":true,"enableSolutionAssemblerLinks":true,"enableStoreFacetStips":true,"enableStorePickupFacet":true,"enableStorePickupFacetCount":true,"enableSubscribeSave":true,"enable_store_finder_redesign":"on","enhancedShippingEnabled":true,"felEnabled":true,"flex_unifiedPriceBlockEnabled":true,"flexEOLSavedItems":true,"fulfillment_cutoff_messaging":true,"fulfillment_e ...
# 						}
#
# 						function _setUpEventManager () {
# 							var EventManager = window.EventManager.default;
# 			window.EventManager = EventManager;
# 						}
#   </script>
#   <script src="https://assets.bbystatic.com/gvp-f9897faf850836c7acb9489af8cc3088.min.js">
#   </script>
#  </head>
#  <body class="size-l">
#   <script>
#    analyticsQ.dispatch({"type":"TRACK_DATA","deviceClass":"l","pageType":"browse,list,category","templateName":"BRCL","blueprintName":"plp-holiday-browse-l"});
# 					window._do_not_use_me = {"pageType":"browse,list,category"};
#   </script>
#   <div class="None" data-version="2.1.4-master-v1.0" id="shop-digital-ad-caa1843a-cf0b-4c8c-ba15-6e8a0cfc6622">
#    <link href="https://www.bestbuy.com/~assets/bby/_com/shop/digital-ad/dist/client/client-a8d3b316f54523b69c24d6cdbb2d291f.css" rel="stylesheet">
#     <div class="shop-digital-ad">
#      <div class="above-header" data-reactroot="">
#       <div class="app-container outer-container left">
#        <span class="vertical-text ad-text uppercase">
#         advertisement
#        </span>
#        <div class="inner-container" data-size="970x66" data-type="gpt">
#        </div>
#       </div>
#      </div>
#     </div>
#    </link>
#   </div>
#   <script>
#    window.bbyDomainVariable="https://www.bestbuy.com/";window.suggestionsEnabled=true;
#   </script>
#   <!-- HF_v19.26.3 -->
#   <div data-meta-layer='{"env_appServer":"https://www.bestbuy.com"}' id="header-meta-layer" style="display:none;">
#   </div>
#   <header class="enable-fluid" data-live-config='{"abt1329evar":"","abt1443evar":"","abt1501evar":"abTest68","abt1501_is_active":false,"abt1501_test_is_on":false,"abTest_key_data":"UNDEFINED","HF_enableDynamicStoreLocator":true,"HF_enableNotificationManager":true,"EtkDeviceSet":true,"enableFluid":true,"custTimeline_enableInGlobalNav":true,"custTimeline_headerExperienceFingerprint":"2.1.11","custTimeline_headerStatusFingerprint":"2.0.17","custTimeline_accountFingerprint":"0.2.0","custTimeline_useIndividualDataTopics":true,"deltaMeasureSampleSize":"0","enableHeaderStoreLocatorActionLogListener":true}' data-script-host="https://assets.bbystatic.com" id="header">
#    <a class="skip" href="#headerskip" title="Skip to content">
#     Skip to content
#    </a>
#    <div class="fullbleed-wrap">
#     <div class="secondary-wrap">
#      <nav aria-label="Deals and Gifts">
#       <ul class="utility-nav">
#        <li>
#         <a data-lid="hdr_wky" href="https://deals.bestbuy.com/">
#          Weekly Ad
#         </a>
#        </li>
#        <li>
#         <a data-lid="hdr_dotd" href="https://www.bestbuy.com/site/misc/deal-of-the-day/pcmcat248000050016.c?id=pcmcat248000050016">
#          Deal of the Day
#         </a>
#        </li>
#        <li>
#         <a data-lid="hdr_crd" href="https://www.bestbuy.com/site/misc/financing-rewards/pcmcat102500050032.c?id=pcmcat102500050032">
#          Credit Cards
#         </a>
#        </li>
#        <li>
#         <a data-lid="hdr_bbfb" href="https://www.bestbuy.com/site/electronics/bestbuy-business/pcmcat230900050001.c?id=pcmcat230900050001">
#          For Your Business
#         </a>
#        </li>
#        <li>
#         <a data-lid="hdr_gft_crd" href="https://www.bestbuy.com/site/electronics/gift-cards/cat09000.c?id=cat09000">
#          Gift Cards
#         </a>
#        </li>
#        <li>
#         <a data-lid="hdr_bts" href="https://www.bestbuy.com/site/misc/back-to-school/pcmcat334100050000.c?id=pcmcat334100050000">
#          Back to School
#         </a>
#        </li>
#       </ul>
#      </nav>
#      <div class="clearer">
#      </div>
#     </div>
#     <div class="primary-wrap">
#      <div class="logo">
#       <a aria-label="BestBuy.com Homepage" data-lid="hdr_lgo" href="https://www.bestbuy.com" title="BestBuy.com Homepage">
#        <img alt="Best Buy Logo" src="https://assets.bbystatic.com/header-footer/images/bby_logo-a7e90594729ed2e119331378def6c97e.png"/>
#       </a>
#      </div>
#      <div class="search-bar" role="search">
#       <form action="https://www.bestbuy.com/site/searchpage.jsp" method="GET" name="frmSearch">
#        <input aria-label="Type to search. Navigate forward to hear suggestions" class="search-input" id="gh-search-input" maxlength="90" name="st" placeholder="Search Best Buy" type="text" value=""/>
#        <button aria-label="Clear search bar text" class="clear-icon clear-search-icon">
#        </button>
#        <button aria-label="submit search" class="header-search-button" title="Search" type="submit">
#         <span aria-hidden="true" class="hf-icon-search">
#         </span>
#        </button>
#        <input name="_dyncharset" type="hidden" value="UTF-8"/>
#        <input name="id" type="hidden" value="pcat17071"/>
#        <input name="type" type="hidden" value="page"/>
#        <input name="sc" type="hidden" value="Global"/>
#        <input name="cp" type="hidden" value="1"/>
#        <input name="nrp" type="hidden" value=""/>
#        <input name="sp" type="hidden" value=""/>
#        <input name="qp" type="hidden" value=""/>
#        <input name="list" type="hidden" value="n"/>
#        <input name="af" type="hidden" value="true"/>
#        <input name="iht" type="hidden" value="y"/>
#        <input name="usc" type="hidden" value="All Categories"/>
#        <input name="ks" type="hidden" value="960"/>
#        <input id="keys" name="keys" type="hidden" value="keys"/>
#       </form>
#      </div>
#      <ul class="user-menus">
#       <li class="location" id="hf-store-locator" style="display:none;">
#        <a data-env-app-server="https://www.bestbuy.com" data-lid="hdr_stl" href="https://www.bestbuy.com/site/store-locator" id="store-locator-anchor">
#         <span aria-hidden="true" class="hf-icon-stores">
#         </span>
#         <span class="store-text" id="locationId">
#          Store Locator
#         </span>
#         <span class="store-hours" id="storeHours" style="padding-left:5px;">
#         </span>
#        </a>
#       </li>
#       <li class="cart">
#        <a aria-label="Cart" class="cart-link" data-lid="hdr_carticon" href="https://www.bestbuy.com/cart" title="Cart">
#         <span id="cart-text">
#          Cart
#         </span>
#         <div aria-hidden="true" class="count-container">
#         </div>
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="fullbleed-wrap top-space">
#     <div class="globalnav-wrap">
#      <nav aria-label="Main" class="category-nav" role="navigation">
#       <ul class="primary-nav">
#        <li class="nav-item js-navitem main-nav productsMenu">
#         <a aria-controls="group0" aria-expanded="false" aria-haspopup="true" href="javascript:void(0)" id="menu0">
#          Products
#         </a>
#         <div aria-hidden="true" aria-labelledby="menu0" class="level-one-navwrap js-subnav sub-nav sub-nav-group" id="group0" role="group">
#          <div class="level-one-cat-nav">
#           <div class="featured-wrapper">
#            <div class="featured">
#             <h2>
#              Featured
#             </h2>
#             <ul>
#              <li>
#               <a data-lid="ubr_ftr_note10" href="https://www.bestbuy.com/site/samsung-store/learn-about-samsung-galaxy-note10/pcmcat1563307561933.c?id=pcmcat1563307561933">
#                Samsung Note10
#               </a>
#              </li>
#              <li>
#               <a data-lid="ubr_ftr_macbook" href="https://www.bestbuy.com/site/all-laptops/macbooks/pcmcat247400050001.c?id=pcmcat247400050001">
#                Latest MacBooks
#               </a>
#              </li>
#              <li>
#               <a data-lid="ubr_ftr_switch" href="https://www.bestbuy.com/site/promo/nintendo-switch-lite">
#                Nintendo Switch Lite
#               </a>
#              </li>
#              <li>
#               <a data-lid="ubr_ftr_toptv" href="https://www.bestbuy.com/site/promo/tv-deals">
#                Top TV Deals
#               </a>
#              </li>
#              <li>
#               <a data-lid="ubr_ftr_bts" href="https://www.bestbuy.com/site/misc/back-to-school/pcmcat334100050000.c?id=pcmcat334100050000">
#                Back to School
#               </a>
#              </li>
#              <li>
#               <a data-lid="ubr_ftr_aip" href="https://www.bestbuy.com/site/health-fitness-sports/aging-in-place/pcmcat1522420940237.c?id=pcmcat1522420940237">
#                Tech for Aging Well
#               </a>
#              </li>
#             </ul>
#            </div>
#            <div class="shopby">
#             <h2>
#              All Categories
#             </h2>
#             <ul>
#              <li aria-controls="level2Group0" aria-haspopup="true" class="js-navitem sub-nav-parent taphover" id="level2Menu0">
#               <a aria-label="Appliances Menu" data-lid="ubr_app" href="javascript:void(0)">
#                <span class="hf-icon-appliances">
#                </span>
#                Appliances
#               </a>
#               <div aria-hidden="true" aria-labelledby="level2Menu0" class="level-two-cat-navwrap js-subnav sub-childNav" id="level2Group0" role="group">
#                <div class="level-two-cat-nav">
#                 <div class="sub-cat-links">
#                  <h2>
#                   <span class="hf-icon-appliances">
#                   </span>
#                   <a data-lid="ubr_app_dept" href="https://www.bestbuy.com/site/electronics/home-appliances/abcat0900000.c?id=abcat0900000">
#                    Appliances
#                   </a>
#                  </h2>
#                  <div class="column-wrap">
#                   <h3>
#                    Major Kitchen Appliances
#                   </h3>
#                   <ul>
#                    <li>
#                     <a data-lid="ubr_app_sale" href="https://www.bestbuy.com/site/home-appliances/major-appliances-sale-event/pcmcat321600050000.c?id=pcmcat321600050000">
#                      Appliance Sale Event
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_ref" href="https://www.bestbuy.com/site/home-appliances/refrigerators/abcat0901000.c?id=abcat0901000">
#                      Refrigerators
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_dis" href="https://www.bestbuy.com/site/home-appliances/dishwashers/abcat0905000.c?id=abcat0905000">
#                      Dishwashers
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_rng" href="https://www.bestbuy.com/site/ranges-ovens-stoves/ranges/abcat0904003.c?id=abcat0904003">
#                      Ranges
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_cktop" href="https://www.bestbuy.com/site/ranges-ovens-stoves/cooktops/abcat0904001.c?id=abcat0904001">
#                      Cooktops
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_oven" href="https://www.bestbuy.com/site/ranges-ovens-stoves/wall-ovens/abcat0904004.c?id=abcat0904004">
#                      Wall Ovens
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_rhood" href="https://www.bestbuy.com/site/ranges-ovens-stoves/range-hoods/abcat0904002.c?id=abcat0904002">
#                      Range Hoods &amp; Ventilation
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_mwv" href="https://www.bestbuy.com/site/home-appliances/microwaves/abcat0903000.c?id=abcat0903000">
#                      Microwaves
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_fre" href="https://www.bestbuy.com/site/home-appliances/freezers-ice-makers/abcat0902000.c?id=abcat0902000">
#                      Freezers &amp; Ice Makers
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_kap1" href="https://www.bestbuy.com/site/featured-offers/kitchen-appliance-packages/pcmcat302600050005.c?id=pcmcat302600050005">
#                      Kitchen Appliance Packages
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                  <div class="column-wrap">
#                   <h3>
#                    Small Kitchen Appliances
#                   </h3>
#                   <ul>
#                    <li>
#                     <a data-lid="ubr_app_sad" href="https://www.bestbuy.com/site/searchpage.jsp?cp=1&amp;searchType=search&amp;_dyncharset=UTF-8&amp;ks=960&amp;sc=Global&amp;list=y&amp;usc=All%20Categories&amp;type=page&amp;id=pcat17071&amp;iht=n&amp;seeAll=&amp;browsedCategory=abcat0900000&amp;st=best%20buy&amp;qp=currentoffers_facet%3DCurrent%20Deals~On%20Sale%5Eproductcategories_facet%3DCategory~abcat0911000%5Eproductcategories_facet%3DCategory~pcmcat302300050021%5Eproductcategories_facet%3DCategory~abcat0915000%5Eproductcategories_facet%3DCategory~abcat0912000&amp;sp=-bestsellingsort%20skuidsaas">
#                      Small Appliance Deals
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_cte" href="https://www.bestbuy.com/site/small-appliances/coffee-tea-espresso/pcmcat367400050002.c?id=pcmcat367400050002">
#                      Coffee, Tea &amp; Espresso
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_mix" href="https://www.bestbuy.com/site/small-appliances/mixers/abcat0912018.c?id=abcat0912018">
#                      Mixers
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_bnj" href="https://www.bestbuy.com/site/small-appliances/blenders-juicers/abcat0912011.c?id=abcat0912011">
#                      Blenders &amp; Juicers
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_bar" href="https://www.bestbuy.com/site/small-appliances/bar-accessories/pcmcat748301695363.c?id=pcmcat748301695363">
#                      Bar &amp; Wine
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_mf" href="https://www.bestbuy.com/site/small-appliances/mini-fridges/abcat0901002.c?id=abcat0901002">
#                      Mini Fridges
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_tpz" href="https://www.bestbuy.com/site/small-appliances/toaster-ovens-pizza-ovens/abcat0912022.c?id=abcat0912022">
#                      Toaster &amp; Pizza Ovens
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_fryers" href="https://www.bestbuy.com/site/small-appliances/fryers/abcat0912013.c?id=abcat0912013">
#                      Air Fryers &amp; Deep Fryers
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_pressure" href="https://www.bestbuy.com/site/steamers-rice-cookers-pressure-cookers/pressure-cookers/pcmcat309100050002.c?id=pcmcat309100050002">
#                      Pressure Cookers
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_all" href="https://www.bestbuy.com/site/home-appliances/small-appliances/abcat0912000.c?id=abcat0912000">
#                      Shop All Small Kitchen Appliances
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                  <div class="column-wrap">
#                   <h3>
#                    Laundry
#                   </h3>
#                   <ul>
#                    <li>
#                     <a data-lid="ubr_app_wdr" href="https://www.bestbuy.com/site/home-appliances/washers-dryers/abcat0910000.c?id=abcat0910000">
#                      Washers &amp; Dryers
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_lpck" href="https://www.bestbuy.com/site/featured-offers/laundry-packages/pcmcat303000050004.c?id=pcmcat303000050004">
#                      Washer &amp; Dryer Bundles
#                     </a>
#                    </li>
#                   </ul>
#                   <h3>
#                    Floor Care &amp; Home Air
#                   </h3>
#                   <ul>
#                    <li>
#                     <a data-lid="ubr_app_vau" href="https://www.bestbuy.com/site/home-appliances/vacuums-floor-care/abcat0911000.c?id=abcat0911000">
#                      Vacuum Cleaners &amp; Floor Care
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_hca" href="https://www.bestbuy.com/site/home-appliances/heating-cooling-air-quality/pcmcat302300050021.c?id=pcmcat302300050021">
#                      Heating, Cooling &amp; Air Quality
#                     </a>
#                    </li>
#                   </ul>
#                   <h3>
#                    Services &amp; Support
#                   </h3>
#                   <ul>
#                    <li>
#                     <a data-lid="ubr_app_measure" href="https://www.bestbuy.com/site/home-appliances/appliance-measuring-delivery-install/pcmcat1515786237448.c?id=pcmcat1515786237448">
#                      How to Measure for New Appliances
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_iha" href="https://www.bestbuy.com/site/in-home-consultation/free-appliance-consultation/pcmcat1501616336885.c?id=pcmcat1501616336885">
#                      Free In-Home Consultation
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_ss_dha" href="https://www.bestbuy.com/site/services/appliance-services/pcmcat255100050002.c?id=pcmcat255100050002">
#                      Delivery, Installation &amp; Haul-Away
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_app_warepu" href="https://www.bestbuy.com/site/home-appliances/warehouse-pickup/pcmcat1547493805250.c?id=pcmcat1547493805250">
#                      Same-Day Appliance Pickup
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                  <div class="clearer">
#                  </div>
#                  <div class="pencil-strip">
#                   <a data-lid="ubr_app_salebanner" href="https://www.bestbuy.com/site/home-appliances/major-appliances-sale-event/pcmcat321600050000.c?id=pcmcat321600050000">
#                    <img alt="Save up to 30% on appliance Top Deals. Exclusions apply. Minimum savings is 5%. Shop appliances." class="b-lazy" data-src="https://pisces.bbystatic.com/image2/BestBuy_US/Gallery/uber_nav_30_sol50278-84758.jpg" src="..."/>
#                   </a>
#                  </div>
#                 </div>
#                 <div class="related-links">
#                  <h3>
#                   Appliance Brands
#                  </h3>
#                  <ul>
#                   <li>
#                    <a data-lid="ubr_app_samsung" href="https://www.bestbuy.com/site/samsung-store/samsung-technology/pcmcat332900050016.c?id=pcmcat332900050016">
#                     Samsung
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_app_lg" href="https://www.bestbuy.com/site/lg/lg-appliances/pcmcat133000050032.c?id=pcmcat133000050032">
#                     LG
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_app_whirl" href="https://www.bestbuy.com/site/brands/whirlpool/pcmcat157300050001.c?id=pcmcat157300050001">
#                     Whirlpool
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_app_kaid" href="https://www.bestbuy.com/site/brands/kitchenaid/pcmcat318300050003.c?id=pcmcat318300050003">
#                     KitchenAid
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_app_maytag" href="https://www.bestbuy.com/site/brands/maytag/pcmcat748301987867.c?id=pcmcat748301987867">
#                     Maytag
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_app_bosch" href="https://www.bestbuy.com/site/brands/bosch/pcmcat208400050010.c?id=pcmcat208400050010">
#                     Bosch
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_app_ge" href="https://www.bestbuy.com/site/brands/ge/pcmcat158500050029.c?id=pcmcat158500050029">
#                     GE
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_app_cafe" href="https://www.bestbuy.com/site/brands/cafe-appliances/pcmcat1535052809504.c?id=pcmcat1535052809504">
#                     Café
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_app_insig" href="https://www.bestbuy.com/site/brands/insignia/pcmcat159800050007.c?id=pcmcat159800050007">
#                     Insignia
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_app_keurig" href="https://www.bestbuy.com/site/brands/keurig/pcmcat338300050016.c?id=pcmcat338300050016">
#                     Keurig
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_app_dyson" href="https://www.bestbuy.com/site/brands/dyson/pcmcat162500050026.c?id=pcmcat162500050026">
#                     Dyson
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_app_irob" href="https://www.bestbuy.com/site/brands/irobot/pcmcat269700050002.c?id=pcmcat269700050002">
#                     iRobot
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_app_shark" href="https://www.bestbuy.com/site/brands/shark/pcmcat344200050025.c?id=pcmcat344200050025">
#                     Shark
#                    </a>
#                   </li>
#                  </ul>
#                 </div>
#                 <div class="clearer">
#                 </div>
#                </div>
#                <div class="clearer">
#                </div>
#                <div class="close-nav level-two">
#                 <a href="javascript:void(0)">
#                  Close
#                 </a>
#                </div>
#               </div>
#              </li>
#              <li aria-controls="level2Group1" aria-haspopup="true" class="js-navitem sub-nav-parent taphover" id="level2Menu1">
#               <a aria-label="TV &amp; Home Theater Menu" data-lid="ubr_tv" href="javascript:void(0)">
#                <span class="hf-icon-tv">
#                </span>
#                TV &amp; Home Theater
#               </a>
#               <div aria-hidden="true" aria-labelledby="level2Menu1" class="level-two-cat-navwrap js-subnav sub-childNav" id="level2Group1" role="group">
#                <div class="level-two-cat-nav">
#                 <div class="sub-cat-links">
#                  <h2>
#                   <span class="hf-icon-tv">
#                   </span>
#                   <a data-lid="ubr_tv_dept" href="https://www.bestbuy.com/site/electronics/tv-home-theater/abcat0100000.c?id=abcat0100000">
#                    TV &amp; Home Theater
#                   </a>
#                  </h2>
#                  <div class="column-wrap">
#                   <h3>
#                    TVs by Size
#                   </h3>
#                   <ul>
#                    <li>
#                     <a data-lid="ubr_tv_75" href="https://www.bestbuy.com/site/tvs/75-inch-tvs/pcmcat1514910595284.c?id=pcmcat1514910595284">
#                      75-Inch or Larger TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_70" href="https://www.bestbuy.com/site/tvs/70-inch-tvs/pcmcat1539183029417.c?id=pcmcat1539183029417">
#                      70-Inch TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_65" href="https://www.bestbuy.com/site/tvs/65-inch-tvs/pcmcat1514910447059.c?id=pcmcat1514910447059">
#                      65-Inch TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_55" href="https://www.bestbuy.com/site/tvs/55-inch-tvs/pcmcat1514910111435.c?id=pcmcat1514910111435">
#                      55-Inch TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_50" href="https://www.bestbuy.com/site/tvs/50-inch-tvs/pcmcat1514909922712.c?id=pcmcat1514909922712">
#                      50-Inch TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_43" href="https://www.bestbuy.com/site/tvs/43-inch-tvs/pcmcat1522873788991.c?id=pcmcat1522873788991">
#                      43-Inch TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_40" href="https://www.bestbuy.com/site/tvs/40-inch-tvs/pcmcat1514909744071.c?id=pcmcat1514909744071">
#                      40-Inch TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_32" href="https://www.bestbuy.com/site/tvs/32-inch-tvs/pcmcat1513872418342.c?id=pcmcat1513872418342">
#                      32-Inch TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_tvs" href="https://www.bestbuy.com/site/tvs/all-flat-screen-tvs/abcat0101001.c?id=abcat0101001">
#                      Shop All Televisions
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                  <div class="column-wrap">
#                   <h3>
#                    TVs by Type
#                   </h3>
#                   <ul>
#                    <li>
#                     <a data-lid="ubr_tv_toptv" href="https://www.bestbuy.com/site/promo/tv-deals">
#                      Top TV Deals
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_u500" href="https://www.bestbuy.com/site/tvs/tvs-under-500/pcmcat1539183860210.c?id=pcmcat1539183860210">
#                      TVs Under $500
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_uhd" href="https://www.bestbuy.com/site/tvs/4k-ultra-hd-tvs/pcmcat333800050003.c?id=pcmcat333800050003">
#                      4K Ultra HD TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_smt" href="https://www.bestbuy.com/site/tvs/smart-tvs/pcmcat220700050011.c?id=pcmcat220700050011">
#                      Smart TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_crv" href="https://www.bestbuy.com/site/tvs/curved-tvs/pcmcat333800050004.c?id=pcmcat333800050004">
#                      Curved TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_oed" href="https://www.bestbuy.com/site/tvs/oled-tvs/pcmcat301000050010.c?id=pcmcat301000050010">
#                      OLED TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_led" href="https://www.bestbuy.com/site/tvs/led-tvs/pcmcat193400050018.c?id=pcmcat193400050018">
#                      LED TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_out" href="https://www.bestbuy.com/site/tvs/outdoor-tvs/pcmcat333800050005.c?id=pcmcat333800050005">
#                      Outdoor TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_8k" href="https://www.bestbuy.com/site/tvs/8k-tvs/pcmcat1552503373763.c?id=pcmcat1552503373763">
#                      8K TVs
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_prem" href="https://www.bestbuy.com/site/magnolia-tv-home-theater/magnolia-home-theater-tvs/pcmcat143200050016.c?id=pcmcat143200050016">
#                      Premium TVs
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                  <div class="column-wrap">
#                   <h3>
#                    Home Theater &amp; Audio
#                   </h3>
#                   <ul>
#                    <li>
#                     <a data-lid="ubr_tv_hts" href="https://www.bestbuy.com/site/home-audio-systems/home-theater-systems/abcat0203000.c?id=abcat0203000">
#                      Home Theater Systems
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_sbr" href="https://www.bestbuy.com/site/speakers/sound-bars/abcat0205007.c?id=abcat0205007">
#                      Sound Bars
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_acc_stf" href="https://www.bestbuy.com/site/tv-home-theater/tv-stands-mounts-furniture/abcat0106000.c?id=abcat0106000">
#                      TV Stands, Mounts &amp; Furniture
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_dvd" href="https://www.bestbuy.com/site/tv-home-theater/blu-ray-dvd-players/abcat0102000.c?id=abcat0102000">
#                      Blu-ray &amp; DVD Players
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_had" href="https://www.bestbuy.com/site/audio/home-audio-systems/pcmcat241600050001.c?id=pcmcat241600050001">
#                      Home Audio Components
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_prj" href="https://www.bestbuy.com/site/tv-home-theater/projectors-screens/pcmcat158900050008.c?id=pcmcat158900050008">
#                      Projectors &amp; Screens
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_smp" href="https://www.bestbuy.com/site/tv-home-theater/streaming-media-devices/pcmcat161100050040.c?id=pcmcat161100050040">
#                      Streaming Media Players
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_hdmi" href="https://www.bestbuy.com/site/a-v-cables-connectors/hdmi-cables-adapters/abcat0107020.c?id=abcat0107020">
#                      HDMI Cables
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_tv_acc_saa" href="https://www.bestbuy.com/site/tv-home-theater/tv-video-accessories/abcat0107000.c?id=abcat0107000">
#                      Shop All Accessories
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                  <div class="clearer">
#                  </div>
#                  <div class="pencil-strip">
#                   <a data-lid="ubr_tv_magnolia" href="https://www.bestbuy.com/site/electronics/magnolia/pcmcat1529524080138.c?id=pcmcat1529524080138">
#                    <img alt="Magnolia: Premium audio, video and smart home solutions. Explore Magnolia!" class="b-lazy" data-src="https://pisces.bbystatic.com/image2/BestBuy_US/Gallery/EVN-146216_magnolia_uber-74045.jpg" src="..."/>
#                   </a>
#                  </div>
#                 </div>
#                 <div class="related-links">
#                  <h3>
#                   Services &amp; Support
#                  </h3>
#                  <ul>
#                   <li>
#                    <a data-lid="ubr_tv_ss_tvhs" href="https://www.bestbuy.com/site/services/tv-home-theater-services/pcmcat138100050024.c?id=pcmcat138100050024">
#                     TV &amp; Home Theater Services
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_tv_tts" href="https://www.bestbuy.com/site/total-tech-support/tv-home-theater/pcmcat1523037677898.c?id=pcmcat1523037677898">
#                     Total Tech Support Membership
#                    </a>
#                   </li>
#                  </ul>
#                  <h3>
#                   Buying Help
#                  </h3>
#                  <ul>
#                   <li>
#                    <a data-lid="ubr_tv_find" href="https://www.bestbuy.com/site/tvs/guided-buying-tv/pcmcat748302046702.c?id=pcmcat748302046702">
#                     Find the Perfect TV
#                    </a>
#                   </li>
#                  </ul>
#                  <h3>
#                   Outlet
#                  </h3>
#                  <ul>
#                   <li>
#                    <a data-lid="ubr_tv_do_tvob" href="https://www.bestbuy.com/site/outlet-refurbished-clearance/tv-home-theater/pcmcat748300667645.c?id=pcmcat748300667645&amp;qp=condition_facet%3DCondition~Open-Box">
#                     TV &amp; Home Theater Open-Box
#                    </a>
#                   </li>
#                  </ul>
#                  <h3>
#                   In-Store Experience
#                  </h3>
#                  <ul>
#                   <li>
#                    <a data-lid="ubr_tv_ise_mht" href="https://www.bestbuy.com/site/electronics/magnolia/pcmcat1529524080138.c?id=pcmcat1529524080138">
#                     Magnolia
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_tv_ise_ses" href="https://www.bestbuy.com/site/samsung-store/samsung-entertainment-experience/pcmcat331700050004.c?id=pcmcat331700050004">
#                     Samsung Entertainment Experience
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_tv_ise_snes" href="https://www.bestbuy.com/site/sony-store/sony-experience/pcmcat331500050001.c?id=pcmcat331500050001">
#                     Sony Experience Shop
#                    </a>
#                   </li>
#                   <li>
#                    <a data-lid="ubr_tv_ise_lge" href="https://www.bestbuy.com/site/lg/lg-tv-and-home-theater/pcmcat310100050001.c?id=pcmcat310100050001">
#                     LG Experience
#                    </a>
#                   </li>
#                  </ul>
#                 </div>
#                 <div class="clearer">
#                 </div>
#                </div>
#                <div class="clearer">
#                </div>
#                <div class="close-nav level-two">
#                 <a href="javascript:void(0)">
#                  Close
#                 </a>
#                </div>
#               </div>
#              </li>
#              <li aria-controls="level2Group2" aria-haspopup="true" class="js-navitem sub-nav-parent taphover" id="level2Menu2">
#               <a aria-label="Computers &amp; Tablets Menu" data-lid="ubr_cp" href="javascript:void(0)">
#                <span class="hf-icon-computers">
#                </span>
#                Computers &amp; Tablets
#               </a>
#               <div aria-hidden="true" aria-labelledby="level2Menu2" class="level-two-cat-navwrap js-subnav sub-childNav" id="level2Group2" role="group">
#                <div class="level-two-cat-nav">
#                 <div class="sub-cat-links">
#                  <h2>
#                   <span class="hf-icon-computers">
#                   </span>
#                   <a data-lid="ubr_cp_dept" href="https://www.bestbuy.com/site/electronics/computers-pcs/abcat0500000.c?id=abcat0500000">
#                    Computers &amp; Tablets
#                   </a>
#                  </h2>
#                  <div class="column-wrap">
#                   <h3>
#                    Computers
#                   </h3>
#                   <ul>
#                    <li>
#                     <a data-lid="ubr_cp_lnb" href="https://www.bestbuy.com/site/computers-pcs/laptop-computers/abcat0502000.c?id=abcat0502000">
#                      Laptops
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_cp_dsk" href="https://www.bestbuy.com/site/computers-pcs/desktop-computers/abcat0501000.c?id=abcat0501000">
#                      Desktops &amp; All-in-One Computers
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_cp_2in1" href="https://www.bestbuy.com/site/all-laptops/2-in-1-laptops/pcmcat309300050015.c?id=pcmcat309300050015">
#                      2-in-1s
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_cp_macbk" href="https://www.bestbuy.com/site/all-laptops/macbooks/pcmcat247400050001.c?id=pcmcat247400050001">
#                      MacBook
#                     </a>
#                    </li>
#                   </ul>
#                   <h3>
#                    Tablets &amp; Accessories
#                   </h3>
#                   <ul>
#                    <li>
#                     <a data-lid="ubr_cp_ipd" href="https://www.bestbuy.com/site/ipad-tablets-ereaders/ipad/pcmcat209000050007.c?id=pcmcat209000050007">
#                      iPad
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_cp_tab" href="https://www.bestbuy.com/site/computers-pcs/ipad-tablets-ereaders/pcmcat209000050006.c?id=pcmcat209000050006">
#                      Tablets
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_cp_ktb" href="https://www.bestbuy.com/site/ipad-tablets-ereaders/kids-tablets/pcmcat313100050038.c?id=pcmcat313100050038">
#                      Kids' Tablets
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_cp_tacc" href="https://www.bestbuy.com/site/computers-pcs/ipad-tablet-ereader-accessories/pcmcat309900050001.c?id=pcmcat309900050001">
#                      iPad &amp; Tablet Accessories
#                     </a>
#                    </li>
#                    <li>
#                     <a data-lid="ubr_cp_erd" href="https://www.bestbuy.com/site/computers-pcs/e-reader-devices/pcmcat193100050014.c?id=pcmcat193100050014">
#                      E-Readers &amp; Accessories
#                     </a>
#                    </li>
#                   </ul>
#                  </div>
#                  <div class="column-wrap">
#                   <h3>
#                    PC Gaming &amp; Virtual Reality
#                   </h3>
#                   <ul>
#                    <li>
#                     <a data-lid="ubr_cp_pcg" href="https://www.bestbuy.com/site/computers-pcs/pc-gaming/abcat0712000.c?id=abcat0712000">
#                      PC Gaming
# ...
#    </script>
#   </div>
#   <script type="text/javascript">
#    var trackData = {
# profileId : "",
# recognized : "Anonymous",
# persistentCart : false,
# guestUser : "true",
# stnum : "960",
# rzTier : "None",
# rzId : "",
# sysDate : "08/09/2019",
# timestamp : "08/09/2019 10:33:08 AM"
#
# };
#   </script>
#   <script src="https://assets.bbystatic.com/optimizely/optimizely.min-0cf8c2d616509221aa049c8557a54b4f.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    window.__optimizelyData = {
# 			data: {"version":"4","rollouts":[],"typedAudiences":[],"anonymizeIP":false,"projectId":"8389272731","variables":[],"featureFlags":[{"experimentIds":[],"rolloutId":"","variables":[{"defaultValue":"150","type":"string","id":"1","key":"BAR_LENGTH"}],"id":"9841960106","key":"STICKY_SEARCH_BAR"}],"experiments":[{"status":"Running","audienceIds":["8565761481","8566382098"],"variations":[{"variables":[],"id":"8929011438","key":"control"},{"variables":[],"id":"8931772184","key":"active"}],"id":"8939301734","key":"applianceCategoryFragment","layerId":"8927531614","trafficAllocation":[{"entityId":"8931772184","endOfRange":5000},{"entityId":"8931772184","endOfRange":10000}],"forcedVariations":{"70271285":"active"}},{"status":"Running","audienceIds":["8565761481","8566382098"],"variations":[{"variables":[],"id":"10962190388","key":"LEGACY_PLP"},{"variables":[],"id":"10956390547","key":"GVP_PLP"}],"id":"10970300236","key":"GVPVSLEGACYPLP","layerId":"10933990301","trafficAllocation":[{"entityId":"10956390547","endOfRange":100},{"entityId":"10956390547","endOfRange":300},{"entityId":"10956390547","endOfRange":500},{"entityId":"10956390547","endOfRange":1000},{"entityId":"10956390547","endOfRange":1500},{"entityId":"10956390547","endOfRange":1750},{"entityId":"10956390547","endOfRange":2000},{"entityId":"10956390547","endOfRange":2500},{"entityId":"10956390547","endOfRange":3750},{"entityId":"10956390547","endOfRange":4000},{"entityId":"10956390547","endOfRange":5000},{"entityId":"10956390547","endOfRange":6000},{"entityId":"10956390547","endOfRange":6250},{"entityId":"10956390547","endOfRange":7000},{"entityId":"10956390547","endOfRange":7500},{"entityId":"10956390547","endOfRange":8000},{"entityId":"10956390547","endOfRange":8500},{"entityId":"10956390547","endOfRange":8750},{"entityId":"10956390547","endOfRange":9000},{"entityId":"10956390547","endOfRange":9500},{"entityId":"10956390547","endOfRange":9700},{"entityId":"10956390547","endOfRange":9900},{"entityId":"10956390547","endOfRange":10000}],"forcedVariations":{"1234":"LEGACY_PLP","123412345":"GVP_PLP","123456789":"LEGACY_PLP","987654321":"GVP_PLP"}},{"status":"Running","audienceIds":[],"variations":[{"variables":[],"id":"11059296619","key":"A"},{"variables":[],"id":"11057303683","key":"B"}],"id":"11061133035","key":"SEARCHAPI","layerId":"11049452452","trafficAllocation":[{"entityId":"11059296619","endOfRange":2000},{"entityId":"11059296619","endOfRange":8000},{"entityId":"11057303683","endOfRange":10000}],"forcedVariations":{"123456789":"A","987654321":"B"}},{"status":"Running","audienceConditions":["or","8566382098","8565761481"],"audienceIds":["8566382098","8565761481"],"variations":[{"variables":[],"id":"11430274296","key":"A"},{"variables":[],"id":"11397965046","key":"B"}],"id":"11408795562","key":"ABT1329_Global_Nav_Optimization_SV","layerId":"11404896725","trafficAllocation":[{"entityId":"11397965046","endOfRange":5000},{"entityId":"11397965046","endOfRange":10000}],"forcedVariations":{"1329":"B","9231":"A","121212121":"A","454545454":"B"}},{"status":"Running","audienceConditions":["or","8565761481"],"audienceIds":["8565761481"],"variations":[{"variables":[],"id":"12122725667","key":"Control"},{"variables":[],"id":"12115534592","key":"B"}],"id":"12115477168","key":"abt985","layerId":"12103645627","trafficAllocation":[{"entityId":"12122725667","endOfRange":5000},{"entityId":"12122725667","endOfRange":9000},{"entityId":"12122725667","endOfRange":10000}],"forcedVariations":{"589":"Control","985":"B","9852":"B"}},{"status":"Running","audienceConditions":["or","8566382098","8565761481"],"audienceIds":["8566382098","8565761481"],"variations":[{"variables":[],"id":"13680390421","key":"browse_sv_holdout"},{"variables":[],"id":"13647650254","key":"browse_sv_sponsored"}],"id":"13657230536","key":"searchTest4","layerId":"13667070104","trafficAllocation":[{"entityId":"13647650254","endOfRange":2000},{"entityId":"13680390421","endOfRange":2500},{"entityId":"13647650254","endOfRange":4000 ...
# 			attrs: {"deviceClass":"l","loggedIn":"false","ptRecognized":"false","oid":"569311047"},
# 			disableOptimizelyShopWebActivation: false
# 		};
#
# 		;(function () {
# 			var data = window.__optimizelyData.data;
# 			var attrs = window.__optimizelyData.attrs;
# 			var id = (document.cookie.match('(^|; )oid=([^;]*)')||0)[2];
# 			var experimentAttr = 'data-optimizely-experiment-key';
# 			var isLoggingActive = /optimizelyLogging=true/i.test(window.location.search);
# 			var evarAttr = 'data-optimizely-evar';
# 			var activeTests = document.querySelectorAll('[' + experimentAttr + ']');
# 			var activatedTests = [];
# 			var config1 =  window.liveConfig ? (window.liveConfig && window.liveConfig.gvp && window.liveConfig.gvp.services ? window.liveConfig.gvp.services.optimizely : {}) : {};
# 			var config2 = window.configService ? window.configService.getServiceConfig('optimizely') : {};
# 			var placebos = (config2 && config2.get && config2.get('placebos') ? config2.get('placebos') : config1.placebos) || [];
# 			var client,variation;
#
# 			window.track = window.track || {};
#
# 			var logLevelMatches = window.location.search.match(/optimizelyLoggingLevel=({d})/i);
# 			var logLevel = logLevelMatches ? logLevelMatches[1] : 2;
# 			var logger = {
# 				log: function (message) {
# 					if (isLoggingActive) {
# 						console.log(message);
# 					}
# 				}
# 			};
#
# 			if (data && attrs && id) {
# 			  client = window.optimizelyClient.createInstance({
# 				  datafile: data,
# 				  skipJSONValidation: true,
# 				  logger: logger,
# 				  logLevel: logLevel
# 			  });
# 			  if (activeTests.length) {
# 				for (var i = 0; i < activeTests.length; i++) {
# 					activate(activeTests[i].getAttribute(experimentAttr), activeTests[i].getAttribute(evarAttr))
# 				}
# 			  }
# 			  if (placebos.length) {
# 				for (var i = 0; i < placebos.length; i++) {
# 				  var placebo = placebos[i];
# 				  try {
# 					  var pageType = window._do_not_use_me ? window._do_not_use_me.pageType : (window.track || {}).pageType;
# 					  if (placebo.locationHrefRegex && new RegExp(placebo.locationHrefRegex).test(window.location.href)) {
# 							activatePlacebo(placebo)
# 					  } else if (placebo.pageTypeRegex && new RegExp(placebo.pageTypeRegex).test(pageType)) {
# 							activatePlacebo(placebo)
# 					  }
# 				  } catch (err) {
# 					  console.log('failed to initialize placebo: ', placebo);
# 				  }
# 				}
# 			  }
# 			}
#
# 			function activate(experimentKey, evar) {
# 				if (activatedTests.indexOf(experimentKey) > -1) return;
# 				var variation = client.activate(experimentKey, id, attrs);
# 				if (evar && variation) {
# 					window.track[evar] = experimentKey + '_Recipe_' + variation;
# 				}
# 				activatedTests.push(experimentKey);
# 				return variation;
# 			}
#
# 			function activatePlacebo(placebo) {
# 				var evar = placebo.evar;
# 				var experimentKey = placebo.experimentKey;
# 				if (experimentKey) {
# 					if (activate(experimentKey, evar) && isLoggingActive) {
# 						console.log('activated placebo');
# 					}
# 				}
# 			}
#
# 			var optimizelyListener = {
# 				type: "addListener",
# 				filter: {
# 					type: "analytics",
# 					name: "trackEvent"
# 				},
# 				handler: function(event) {
# 					var metrics = event.data && event.data.metrics ? event.data.metrics : {};
# 					var tags = event.data && event.data.tags ? event.data.tags : {};
# 					var metricsTags = Object.assign({}, metrics, tags);
# 					var eventName = event.data && event.data.name ? event.data.name.replace(/\(|\)|\s+\//g, '') : '';
#
# 					if (event.data.type === 'pageview') {
# 						eventName = 'Visit Page - ' + eventName;
# 					}
# 					client.track(eventName, id, attrs, metricsTags);
# 				}
# 			}
#
# 			window.optimizely = window.optimizely || [];
# 			window.optimizely.push(optimizelyListener);
# 		})();
#   </script>
#   <script>
#    ;(function () {
# 							if (!document.querySelector('script[src="/~assets/bby/_js/ext/optmzly/8143030612.js"]')) {
# 								var script = document.createElement('script');
# 								script.src = '/~assets/bby/_js/ext/optmzly/8143030612.js';
# 								document.getElementsByTagName('head')[0].appendChild(script);
# 							}
# 					}());
#   </script>
#   <script async="" src="https://assets.bbystatic.com/abtest/abtestInit-f10337b0193d1e04bb06cbe9281a3841.js">
#   </script>
#   <script>
#    window.dioFramework = true;
#   </script>
#   <script async="" src="https://assets.bbystatic.com/analytics-dotcom/analyticsInit-780c2e1e3b91ae9cd36f62e8c83420ca.js">
#   </script>
#   <script async="" src="https://assets.bbystatic.com/@ds/unified-chat/dist/javascript/unified-chat-init-016e7dbd.js">
#   </script>
#   <script async="" src="https://assets.bbystatic.com/timeline-web/loader-1.0.648.js">
#   </script>
#   <script src="https://assets.bbystatic.com/header-footer/main-l-3686ee1818fe4650dfb0.js">
#   </script>
#   <script>
#    "use strict";var _typeof="function"==typeof Symbol&&"symbol"==typeof Symbol.iterator?function(o){return typeof o}:function(o){return o&&"function"==typeof Symbol&&o.constructor===Symbol&&o!==Symbol.prototype?"symbol":typeof o};"object"!==_typeof(window.liveConfig)&&(window.liveConfig={}),"object"!==_typeof(window.liveConfig.dux)&&(window.liveConfig.dux={}),"object"!==_typeof(window.liveConfig.dux['suggestViewClientComponent'])&&(window.liveConfig.dux['suggestViewClientComponent']={"minSuggestCharacters":1,"assetsUrlPrefix":"https://www.bestbuy.com/~assets/bby/_com","enablePopulateTermOnKeystroke":true,"enableProductFlipping":true,"enableProductSuggestion":true,"enableRatings":true,"enableSearchHistoryOnClick":true,"enableSearchHistoryOnTyping":true,"enableSearchHistoryWithCategory":false,"enableSearchWithNoAvailableProductSuggestions":true,"enableWidenedAutocompleteBox":true,"enableLocation":false,"httpRequestUrlPrefix":"https://www.bestbuy.com","httpsRequestUrlPrefix":"https://www.bestbuy.com","keystrokeDebounceTime":2,"numberOfSearchHistoriesOnTyping":3,"pdpUrlPrefix":"http://www.bestbuy.com","productQueryParameters":"","productFlippingDelay":100,"searchHistoryDebounceTime":2,"suggestionQueryParameters":"","useSuggestViewProducts":false,"enableMulticategory":true,"numberOfMulticategories":3,"enableSendTrailingSpaces":true,"useSuggestViewClient":true});
#   </script>
#   <script src="https://assets.bbystatic.com/suggest/suggest-view-client-l-b4dba0f0823911e9b087f7173125b100.js">
#   </script>
#   <script>
#    "use strict";var config=window.liveConfig||{},probability=config.duxValidate||0;if("function"==typeof jQuery&&probability>0&&probability<=1){var result=Math.random()<probability;(1===probability||result)&&!function(){var i={"name":"suggestViewClientComponent","config":{"minSuggestCharacters":1,"assetsUrlPrefix":"https://www.bestbuy.com/~assets/bby/_com","enablePopulateTermOnKeystroke":true,"enableProductFlipping":true,"enableProductSuggestion":true,"enableRatings":true,"enableSearchHistoryOnClick":true,"enableSearchHistoryOnTyping":true,"enableSearchHistoryWithCategory":false,"enableSearchWithNoAvailableProductSuggestions":true,"enableWidenedAutocompleteBox":true,"enableLocation":false,"httpRequestUrlPrefix":"https://www.bestbuy.com","httpsRequestUrlPrefix":"https://www.bestbuy.com","keystrokeDebounceTime":2,"numberOfSearchHistoriesOnTyping":3,"pdpUrlPrefix":"http://www.bestbuy.com","productQueryParameters":"","productFlippingDelay":100,"searchHistoryDebounceTime":2,"suggestionQueryParameters":"","useSuggestViewProducts":false,"enableMulticategory":true,"numberOfMulticategories":3,"enableSendTrailingSpaces":true,"useSuggestViewClient":true},"dependencies":{"js":[{"file":"/suggest/suggest-view-client-l-b4dba0f0823911e9b087f7173125b100.js"}],"css":[]}};if(i.content=window.jQuery("div[data-dux-component="+'suggestViewClientComponent'+"]").html()||"","function"!=typeof window.__duxValidate__){var a=document.createElement("script");a.onload=function(){return window.__duxValidate__(i)},a.src='https://assets.bbystatic.com'+"/lib-dux/dist/validate-"+"a069b97f2596d0f28de17826cac506c6"+".js",document.body.appendChild(a)}else window.__duxValidate__(i)}()}
#   </script>
#   <script async="" defer="" src="//img.bbystatic.com/BestBuy_US/js/tracking/brightTag-min.js">
#   </script>
#   <script type="text/javascript">
#    var _cf = _cf || []; _cf.push(['_setFsp', true]); _cf.push(['_setBm', true]); _cf.push(['_setAu', '/resources/575413acf319279cbf472737f84d78']);
#   </script>
#   <script src="/resources/575413acf319279cbf472737f84d78" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
releases = {}
sold_out_releases = {}
bb1 = "https://www.bestbuy.com/site/music/vinyl-records/pcmcat197800050048.c?cp="
bb2 = "&id=pcmcat197800050048"
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:68.0)'}

for i in range(1,100):
    page = requests.get(bb1 + str(i) + bb2, headers=headers)
    soup = BeautifulSoup(page.text, 'html.parser')
    artist_sku_release_date = soup.find_all('div', class_="sku-model")
    title = soup.find_all('div', class_="sku-title")
    price = soup.find_all('div', class_="priceView-hero-price priceView-customer-price")
    in_stock = soup.find_all('div', class_="fulfillment-add-to-cart-button")
    for num in range(len(artist_sku_release_date)):
        SKU = artist_sku_release_date[num].text[(artist_sku_release_date[num].text.find("SKU:")+4):artist_sku_release_date[num].text.find(" R")]
        if SKU not in releases:
            release_list = []
            #artist name:
            release_list.append(artist_sku_release_date[num].text[7:artist_sku_release_date[num].text.find(" SKU")])
            #release date:
            release_list.append(artist_sku_release_date[num].text[(artist_sku_release_date[num].text.find("Release Date:")+13):])
            #title:
            release_list.append(title[num].text)
            #price:
            release_list.append(price[num].text[35:])
            #type (pre-order, in stock)
            if in_stock[num].text == "Add to Cart":
                release_list.append("In Stock")
            else:
                release_list.append(in_stock[num].text)
            #sku:
            SKU = int(artist_sku_release_date[num].text[(artist_sku_release_date[num].text.find("SKU:")+4):artist_sku_release_date[num].text.find(" Release Date:")])
            if in_stock[num].text == "Sold Out":
                sold_out_releases[SKU] = release_list
            else:
                releases[SKU] = release_list

# %%
print(releases)
print(sold_out_releases)
# Out:
# {6322952: ['Queen', '02/08/2019 ', 'Bohemian Rhapsody [Original Motion Picture Soundtrack] [LP] - VINYL', '29.99', 'In Stock'], 5657026: ['Fleetwood Mac', '06/24/2014 ', 'Greatest Hits [Warner Bros.] [LP] - VINYL', '18.99', 'In Stock'], 5657020: ['Led Zeppelin', '10/27/2014 ', 'Led Zeppelin IV [LP] - VINYL', '23.99', 'In Stock'], 6157818: ['Elton John', '11/10/2017 ', 'Diamonds [LP] - VINYL', '33.99', 'In Stock'], 5678400: ['The Beatles', '11/13/2012 ', 'Abbey Road [LP] - VINYL', '20.99', 'In Stock'], 1304629: ['Journey', '11/01/2011 ', "Journey's Greatest Hits [Bonus LP Version] [LP] - VINYL", '33.99', 'In Stock'], 9504011: ['The Doors', '09/15/2009 ', 'Doors [180 Gram Vinyl] [LP] - VINYL', '23.99', 'In Stock'], 6164570: ['Original Television Soundtrack', '12/15/2017 ', 'Stranger Things [Music from the Netflix Original Series] [LP] - VINYL', '22.99', 'In Stock'], 5658116: ['Elvis Presley', '03/04/2016 ', 'Essential Elvis Presley [RCA/Sony BMG] [Two-LP] [LP] - VINYL', '26.99', 'In Stock'], 5658800: ['Jimi Hendrix', '07/29/2014 ', 'Are You Experienced? [LP] - VINYL', '12.99', 'In Stock'], 6346268: ['The Rolling Stones', '04/19/2019 ', 'Honk [LP] - VINYL', '34.99', 'In Stock'], 6333801: ['King Crimson', '11/22/2010 ', 'In the Court of the Crimson King [LP] - VINYL', '20.99', 'In Stock'], 6348652: ['Khalid', '05/31/2019 ', 'Free Spirit [LP] - VINYL', '24.98', 'In Stock'], 5708825: ['Pink Floyd', '11/04/2016 ', 'Dark Side of the Moon [LP] - VINYL', '29.99', 'In Stock'], 5919821: ['Iron Maiden', '10/27/2014 ', 'Piece of Mind [LP] - VINYL', '20.99', 'In Stock'], 5665801: ['Pink Floyd', '10/14/2016 ', 'Wish You Were Here [LP] - VINYL', '29.99', 'In Stock'], 9384427: ['Bob Marley', '07/07/2009 ', 'Legend [180 Gram Vinyl] [LP] - VINYL', '23.99', 'In Stock'], 5658205: ['The Beatles', '11/13/2012 ', 'Rubber Soul [2012 LP] [LP] - VINYL', '20.99', 'In Stock'], 6114420: ['Metallica', '11/10/2017 ', 'Master of Puppets [LP] - VINYL', '18.99', 'In Stock'], 5661011: ['Frank Sinatra', '06/09/2015 ', 'Ultimate Sinatra [180 Gram Vinyl] [LP] - VINYL', '28.99', 'In Stock'], 6036063: ['Tool', '09/17/1996 Parental Advisory', 'Undertow [LP] [PA]', '28.99', 'In Stock'], 9102133: ['Wu-Tang Clan', '11/09/1993 Parental Advisory', 'Enter the Wu-Tang (36 Chambers) [LP] [PA]', '18.99', 'In Stock'], 9033299: ['Dr. Dre', '05/22/2001 Parental Advisory', 'The Chronic [LP] [PA]', '22.99', 'In Stock'], 5658207: ['Lana Del Rey', '02/21/2012 ', 'Born to Die [LP] - VINYL', '15.99', 'In Stock'], 33103485: ['Kane Brown', '06/30/2017 ', 'Kane Brown [LP] - VINYL', '19.99', 'In Stock'], 5971305: ['Lorde', '11/19/2013 ', 'Pure Heroine [LP] - VINYL', '26.99', 'In Stock'], 5658114: ['Johnny Cash', '03/04/2016 ', 'The Essential Johnny Cash [LP] - VINYL', '26.99', 'In Stock'], 6289121: ['Pink Floyd', '09/28/2018 ', 'The  Best of Pink Floyd: A Foot in the Door [LP] - VINYL', '39.99', 'In Stock'], 5969223: ['Black Sabbath', '02/03/2017 ', 'The Ultimate Collection  [LP] - VINYL', '59.99', 'In Stock'], 9177767: ['Panic! At the Disco', '02/10/2009 ', 'Pretty. Odd. [LP] - VINYL', '18.99', 'In Stock'], 5657050: ['David Bowie', '05/20/2016 ', 'Changesonebowie [Black Vinyl] [LP] - VINYL', '20.99', 'Check Stores'], 6239924: ['Carole King', '05/04/2018 ', 'Her Greatest Hits: Songs of Long Ago [LP] - VINYL', '18.99', 'In Stock'], 5658119: ['Foo Fighters', '11/03/2009 ', 'Greatest Hits [LP] - VINYL', '22.99', 'In Stock'], 5658215: ['The Beach Boys', '06/10/2016 ', 'Pet Sounds [50th Anniversary Stereo Edition] [LP] - VINYL', '23.99', 'In Stock'], 6139220: ['Green Day', '11/17/2017 ', "Greatest Hits: God's Favorite Band [LP] - VINYL", '26.99', 'Check Stores'], 5661019: ['Taylor Swift', '12/09/2014 ', '1989 [LP] - VINYL', '23.99', 'In Stock'], 6297907: ['System of a Down', '10/12/2018 ', 'Toxicity [LP] - VINYL', '15.99', 'In Stock'], 6356892: ['Various Artists', '07/26/2019 ', 'Stranger Things: Soundtrack From the Netflix Original Series, Season 3 [LP] - VINYL', '29.99', 'In Stock'], 5657012:  ...
# {34175147: ['Swans', '07/27/2018 ', 'Soundtracks for the Blind [LP] - VINYL', '69.99', 'Sold Out'], 34662868: ['Ariana Grande', '08/09/2019 ', 'thank u, next [LP] - VINYL', '39.99', 'Sold Out'], 34648864: ['Original Soundtrack', '08/02/2019 ', 'Shrek [Limited Edition] [Black Vinyl] [LP] - VINYL', '16.99', 'Sold Out'], 24677169: ['Kansas', '03/18/2014 ', 'Song for America [LP] - VINYL', '29.99', 'Sold Out'], 27865245: ['Kansas', '09/25/2015 ', 'Two for the Show [LP] - VINYL', '47.99', 'Sold Out'], 34643329: ['Tyler Childers', '08/02/2019 ', 'Country Squire [LP] - VINYL', '19.99', 'Sold Out'], 34501541: ['Justin Adams', '03/01/2019 ', 'Burning Men [Original Motion Picture Soundtrack] [LP] - VINYL', '32.99', 'Sold Out'], 26889904: ['The Beach Boys', '02/17/2015 ', 'Little Deuce Coupe [LP] - VINYL', '39.99', 'Sold Out'], 23359932: ['Baby Dee', '02/04/2014 ', 'The Big Bumble Bees [LP] - VINYL', '19.99', 'Sold Out'], 24676729: ['Fear of Men', '04/22/2014 ', 'Loom [LP] - VINYL', '14.99', 'Sold Out'], 31956247: ['Shadowy Men on a Shadowy Planet', '10/14/2016 ', 'Dim the Lights, Chill the Ham [LP] - VINYL', '19.99', 'Sold Out'], 34623049: ['Volbeat', '08/02/2019 ', 'Rewind, Replay, Rebound [LP] - VINYL', '39.99', 'Sold Out'], 16716038: ['Slipknot', '03/07/2000 Parental Advisory', 'Slipknot [US Bonus Tracks #1]', '19.99', 'Sold Out'], 34453905: ['Sleeping Bag', '07/16/2013 ', 'Women of Your Life [LP] - VINYL', '23.99', 'Sold Out'], 30465846: ['Rick Ross', '03/25/2016 ', 'Port of Miami [LP] - VINYL', '23.99', 'Sold Out'], 20900267: ['The Sound', '02/19/2013 ', 'All Fall Down [LP] - VINYL', '19.99', 'Sold Out'], 33369595: ['Backstreet Girls', '09/08/2017 ', "Don't Mess With My Rock'n'roll [LP] - VINYL", '29.99', 'Sold Out'], 34413466: ['A Forest of Stars', '10/05/2018 ', 'Grave Mounds and Grave Mistakes [LP] - VINYL', '58.99', 'Sold Out'], 19399682: ['High Wolf', '10/25/2011 ', 'Atlas Nation [LP] - VINYL', '19.99', 'Sold Out'], 34576683: ['Mental Cruelty', '05/10/2019 ', 'Inferis [LP] - VINYL', '27.99', 'Sold Out'], 33276007: ['Los Gatos', '06/23/2017 ', 'Los Gatos [LP] - VINYL', '39.99', 'Sold Out'], 21839146: ['Sting', '09/24/2013 ', 'Last Ship [LP] - VINYL', '16.99', 'Sold Out'], 26019998: ['Thin Lizzy', '12/16/2014 ', 'Thunder and Lightning [LP] - VINYL', '32.99', 'Sold Out'], 34431821: ['Pooh', '11/30/2018 ', "L' Ultimo Abbraccio: Picture 1 [LP] - VINYL", '47.99', 'Sold Out'], 17172444: ['The Octopus Project', '12/18/2007 ', 'Hello, Avalanche [LP] - VINYL', '14.99', 'Sold Out'], 25208283: ['Coppelius', '04/22/2014 ', 'Extrablatt [LP] - VINYL', '39.99', 'Sold Out'], 22510353: ['dBridge', '10/06/2009 ', 'Memoirs of an Afterlife [LP] - VINYL', '39.99', 'Sold Out'], 31804675: ['Serge Gainsbourg', '07/01/2016 ', 'Du Chant à la Une! [LP] - VINYL', '23.99', 'Sold Out'], 25352147: ['Dinosaur Jr.', '07/08/2014 ', 'Hand It Over [LP] - VINYL', '29.99', 'Sold Out'], 24204207: ['Sabina', '03/11/2014 ', 'Toujours [LP] - VINYL', '17.99', 'Sold Out'], 18739333: ['Elf Power', '09/14/2010 ', 'Elf Power [LP] - VINYL', '16.99', 'Sold Out'], 27924536: ['Dinah Washington', '05/12/2015 ', 'In the Land of Hi-Fi [LP] - VINYL', '14.99', 'Sold Out'], 17642605: ['O+S', '03/24/2009 ', 'O+S [LP] - VINYL', '16.99', 'Sold Out'], 24187059: ['Floor', '02/04/2014 ', 'Floor [LP] - VINYL', '23.99', 'Sold Out'], 32520051: ['Color Filter', '01/27/2017 ', 'Remix [LP] - VINYL', '.99', 'Sold Out'], 32561425: ['Bayley,Blaze', '03/10/2017 ', 'Infinite Entanglement (Uk) - VINYL', '29.99', 'Sold Out'], 21677931: ['Nightrage', '07/08/2013 ', 'Insidious [LP] - VINYL', '29.99', 'Sold Out'], 25897551: ['Monarch!', '11/11/2014 ', 'Omens [LP] - VINYL', '47.99', 'Sold Out'], 34454986: ['The Delta 72', '08/12/1997 ', 'The Soul of a New Machine [LP] - VINYL', '.99', 'Sold Out'], 33913099: ['Manfred Hübler', '03/09/2018 ', 'Psychedelic Dance Party [LP] - VINYL', '47.99', 'Sold Out'], 34229748: ['Guido De Angelis', '07/13/2018 ', 'La  Tigre e Ancora Viva: Sandokan Alla Riscossa! [LP] - VIN ...

# %%
import csv
import datetime

# %%
releases_csv = "releases-" + str(datetime.date.today()) + ".csv"
with open(releases_csv, "w") as outfile:
   writer = csv.writer(outfile)
   writer.writerows(releases.values())
